# %%
import pandas as pd
import sklearn as sk
from sklearn.cluster import KMeans
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn import svm
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.model_selection import cross_val_score, train_test_split, cross_val_predict
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score
pd.set_option('display.max_columns', 25)
pd.set_option('display.max_rows', 25)
Df = pd.read_csv("12Buckets.csv")
FA = pd.read_csv("FreeAgents.csv")
CapSpace = pd.read_csv("CapSpace.csv")
DfUngrouped = pd.read_csv('SalaryData.csv')

# %%
def GetMascot(x):
    mascotsplit = x['Team'].split('-')
    mascot = mascotsplit[1]
    return mascot

DfUngrouped['Team'] = DfUngrouped.apply(GetMascot,axis = 1)
DfUngrouped.head()
# Out:
#    CapPerc Cash  DeadCap  IR           Player Position  Prac SalaryCap  Susp  \
# 0      inf    -        1   0       Cody Brown       DE     0    239000     0
# 1      inf    -        1   0    Anthony Becht       TE     0     50000     0
# 2      inf    -        1   0   Jorrick Calvin       CB     0     22058     0
# 3      inf    -        1   0  Trevor Canfield        G     0     17650     0
# 4      inf    -        1   0       Jason Elam        K     0   1250000     0
#
#         Team  Year
# 0  cardinals  2010
# 1  cardinals  2010
# 2  cardinals  2010
# 3  cardinals  2010
# 4    falcons  2010

# %%
global Groups
global GroupToPos
global SalaryCaps
Groups = ['Safeties','Corners','InsideBackers','Edge','InteriorDLine','WRs','TEs','InteriorOLine','Tackles','QB','RB','Special']
GroupToPos = {'Safeties': ['SS','S','FS'], 'Corners': ['CB'], 'InsideBackers': ['LB','ILB'], 'InteriorDLine': ['DT']
             , 'Edge': ['OLB', 'DE'], 'TEs': ['TE'], 'WRs': ['WR'], 'InteriorOLine': ['G', 'C', 'OL'], 'Tackles': ['T','LT','RT'],
             'QB': ['QB'], 'RB': ['RB'], 'Special': ['K','P','KR','PR','LS']}
SalaryCaps = {2009: 123000000, 2011: 120000000, 2012: 120600000, 2013: 123000000, 2014: 133000000, 2015: 143280000, 2016: 155270000, 2017: 167000000
             , 2018: 177200000, 2019: 188200000, 2020: 198200000}

Df.head()
# Out:
#    Year       Team  Safeties  Corners  InsideBackers   Edge  InteriorDLine  \
# 0  2005  cardinals      8.02     3.09           2.08   9.11           1.47
# 1  2006  cardinals      9.22     0.95           2.46  11.08           3.72
# 2  2007  cardinals      8.73     1.48           3.39  11.32           1.64
# 3  2008  cardinals      8.13     2.29           9.81   8.31           3.75
# 4  2009  cardinals     10.10     8.03          10.46   6.54           7.00
#
#      WRs   TEs  InteriorOLine  Tackles     QB     RB  Special  Dead     IR  \
# 0   8.76  0.44          15.55     5.49   6.72   0.81     3.03  8.08   0.16
# 1  11.23  0.81          20.40     3.43   6.87  10.18     1.76  1.18   0.61
# 2  10.80  0.95          10.49     5.60   8.55   7.57     1.13  2.07  13.01
# 3  11.07  1.67          11.33    13.31   7.49   7.27     0.80  4.09   0.23
# 4  14.14  0.66           9.37     8.26  12.29   4.53     2.21  6.92   5.68
#
#    Prac  Susp  Wins  Playoff Wins  SuperBowl Win
# 0  0.09   0.0     5             0              0
# 1  0.15   0.0     5             0              0
# 2  0.08   0.0     8             0              0
# 3  0.32   0.0     9             3              0
# 4  0.21   0.0    10             1              0

# %%
#Normalize spending percentages to the year each team existed in, allowing for comparison and for reasonable distance calculation
def Normalize(x):
    RetList = []
    for position in Groups:
        dfyear = Df[Df['Year'] == x['Year']]
        val = (x[position] - np.mean(dfyear[position]))/(np.std(dfyear[position]))
        
        RetList.append(val)
    
    return pd.Series(RetList)
    
    
    
Df[Groups] = Df.apply(Normalize, axis = 1)

# %%
def DistAllTeams(x, Team, Year):
    TheTeam = Df[(Df['Team'] == Team)&(Df['Year'] == Year)]
    TotD = 0
    if ((x['Team'] == Team)|(x['Year'] >= Year)):
        Dist = 100
    
    else:
        for Position in Groups:
            Di = (x[Position]-TheTeam[Position])**2
            TotD += Di
        Dist = np.sqrt(TotD)
    return Dist

def BasicRecommend(x):
    if (x['Wins'] > 0)&(x['Playoff Wins'] > 0):
        message = "Increase spending in this position"
    
    elif (x['Wins'] < 0)&(x['Playoff Wins'] < 0):
        message = "Decrease spending in this position"
        
    else:
        message = "No clear direction from historical data"
        
    return message
    

def FullComparable(Team, Year):
    ChangeFrame = pd.DataFrame()  
    Groups2 = Groups.copy()
    Groups2.extend(['Dead','IR','Prac','Susp','Wins','Playoff Wins'])
    Df['Dist'] = Df.apply(DistAllTeams, axis = 1, args = (Team, Year))
    
    #Check the 5 teams that are most similar to the team in question
    
    ######
    for l in range(0,11):
        
        TopTeams = Df.sort_values(by = "Dist")[l:l+1]
        NextYear = Df[(Df['Team'] == TopTeams.iloc[0,1])&(Df['Year'] == TopTeams.iloc[0,0]+1)]
        
        Result2 = TopTeams.copy()
        for i in range(0,len(Groups2)):
            Position = Groups2[i]
            NewVal = NextYear[Position].values - TopTeams[Position].values
            Result2.iloc[0,i+2] = NewVal

        Result2.iloc[0,0] = str(TopTeams['Year'].values[0]) + " to " +  str(NextYear['Year'].values[0])

        ChangeFrame = ChangeFrame.append(Result2)

    X = ChangeFrame.copy()
    display(X)
    cor = X.corr(method = "spearman").fillna(0)
    cor['Recommendation'] = cor.apply(BasicRecommend, axis = 1)
    #PlayerRecommendations = SpecificRecs(cor)
    display(cor[['Wins','Playoff Wins','Recommendation']][0:12])
    return cor

# %%
cor = FullComparable('texans',2019)
# Out:
#              Year       Team  Safeties   Corners  InsideBackers      Edge  \
# 147  2017 to 2018    broncos -0.227726 -0.221059       0.485421 -0.923957
# 68   2013 to 2014   panthers -0.599165 -1.303598      -1.431763  0.926090
# 372  2017 to 2018       jets  0.479181  1.438337       0.611306 -0.853272
# 350  2010 to 2011     giants -0.490560 -0.578400      -0.051792  0.057030
# 8    2013 to 2014  cardinals  0.379439  1.289573      -0.166973  0.785393
# 373  2018 to 2019       jets  0.145432 -1.373145       2.545242 -1.117656
# 36   2011 to 2012     ravens  0.500458 -0.311136       0.253507 -0.906201
# 102  2017 to 2018    bengals -0.776392 -0.090792      -0.294344  0.464682
# 75   2005 to 2006      bears -0.291316 -0.199126      -0.045566 -0.454203
# 466  2006 to 2007   redskins  2.651799  0.068489       0.433420 -3.356136
# 76   2006 to 2007      bears -0.085121  1.449581      -0.116768  1.275774
#
#      InteriorDLine       WRs       TEs  InteriorOLine   Tackles        QB  \
# 147       0.176749 -1.961223 -0.427315       0.270024 -0.233475  1.210933
# 68        0.014885 -1.618021  1.560332      -1.389068 -0.075853 -0.120452
# 372       0.164478  1.416239  0.323308       0.168854  0.778616  0.849767
# 350      -0.163821 -0.612397 -0.559156      -0.104974  0.096666  1.096531
# 8         0.294426 -0.382292  0.135165      -2.225174 -0.095647  1.371731
# 373       0.392088 -0.208207 -0.283069      -0.838383 -0.564164 -0.924091
# 36        0.684663 -0.264289 -0.602289      -1.629572  0.274676  0.374219
# 102       0.703372 -0.565916  0.528613      -1.118845  2.562630 -0.244166
# 75       -0.328375  0.265262 -0.187331       0.109776  0.373157 -0.158845
# 466       0.273794 -0.116366  0.199372      -0.956799 -0.274220 -0.414782
# 76        0.342153 -0.755169  0.314846      -0.483943 -0.695818  0.056422
#
#            RB   Special   Dead     IR  Prac  Susp  Wins  Playoff Wins  \
# 147 -1.335786  0.568758   0.06   3.84  0.00  0.00     1             0
# 68   0.354302 -0.732605 -14.19  -5.79  3.28  0.00    -5             0
# 372 -0.493766  0.208528  13.36   4.68  0.00  1.43    -1             0
# 350  1.305026  0.208135   2.73  -2.41 -0.07  0.00    -1             4
# 8   -0.909775 -1.207306  -0.25  14.89  0.15  2.25     1             0
# 373  0.602079 -0.199796 -13.29  11.55  0.00 -1.43     3             0
# 36   1.181989 -0.764452   6.47   6.74 -0.18  0.00    -2             2
# 102 -0.412581 -0.067922  -0.67  14.90  0.00  0.00    -1             0
# 75   0.323016 -0.062739   2.73  -0.21  0.00  0.00     2             2
# 466 -0.914128  0.231155 -10.29   7.65 -0.08  0.00     4             0
# 76  -0.809172  0.027756  -1.43   3.00  0.00  0.00    -6            -3
#
#      SuperBowl Win      Dist
# 147              0  2.552742
# 68               0  2.892511
# 372              0  2.962586
# 350              0  2.978551
# 8                0  3.084760
# 373              0  3.088746
# 36               0  3.266323
# 102              0  3.407493
# 75               0  3.414698
# 466              0  3.416787
# 76               0  3.418914
#                    Wins  Playoff Wins                           Recommendation
# Safeties       0.308066     -0.095053  No clear direction from historical data
# Corners       -0.110352     -0.496390       Decrease spending in this position
# InsideBackers  0.533369      0.068650       Increase spending in this position
# Edge          -0.717289     -0.242914       Decrease spending in this position
# InteriorDLine -0.110352     -0.385494       Decrease spending in this position
# WRs            0.491987      0.237633       Increase spending in this position
# TEs           -0.262086     -0.623127       Decrease spending in this position
# InteriorOLine  0.174724      0.036965       Increase spending in this position
# Tackles       -0.160930      0.512232  No clear direction from historical data
# QB            -0.308066      0.142580  No clear direction from historical data
# RB            -0.285076      0.638970  No clear direction from historical data
# Special        0.248292     -0.105615  No clear direction from historical data

# %%
def SpecificRecs(Team, Year, FreeAgents):
    cor = FullComparable(Team, Year)
    cor = cor[['Wins','Playoff Wins','Recommendation']][0:12].sort_values(by = "Wins")
    PossibleFA = FA[FA['Year'] == Year]
    RecommendedFA = pd.DataFrame(columns = ['AAV','Age','CapPerc','Dollars','From','Player','Position','To','Year','Years'])
    RecommendToCut = pd.DataFrame(columns = ['CapPerc','Cash','DeadCap','IR','Player','Position','Prac','SalaryCap','Susp','Team','Year'])
    PosToInc = 0
    PosToDec = 0
    for i in range(0,len(cor)):
        row = cor.iloc[i]
        if row['Recommendation'] == 'Increase spending in this position':
            group = cor.index[i]
            Positions = GroupToPos[group]
            RecommendedFA = RecommendedFA.append(PossibleFA[PossibleFA['Position'].isin(Positions)])
            PosToInc += 1
        elif row['Recommendation'] == 'Decrease spending in this position':
            group = cor.index[i]
            Positions = GroupToPos[group]
            RecommendToCut = RecommendToCut.append(DfUngrouped[(DfUngrouped['Team'] == Team)&(DfUngrouped['Year'] == Year)&(DfUngrouped['Position'].isin(Positions))])
            
            
    SalaryCap = SalaryCaps[Year]
    TeamCapSpace = CapSpace[(CapSpace['Year'] == Year)&(CapSpace['Team'] == Team)]
    
    ##Just have it return one player to sign and one player to cut
    SignPlayer = RecommendedFA.sort_values(by = 'AAV')
    CutPlayer = RecommendToCut.sort_values(by = 'SalaryCap')
    
    PlayerRecs = {'Sign': SignPlayer, 'Cut': CutPlayer}
    
            
            
    return PlayerRecs

# %%
SpecificRecs('texans', 2018, FA)
# Out:
#              Year        Team  Safeties   Corners  InsideBackers      Edge  \
# 147  2017 to 2018     broncos -0.227726 -0.221059       0.485421 -0.923957
# 36   2011 to 2012      ravens  0.500458 -0.311136       0.253507 -0.906201
# 392  2007 to 2008    steelers  1.096584 -0.862205      -2.205165 -0.457518
# 146  2016 to 2017     broncos -0.872813 -0.054636       0.511560  0.068000
# 35   2010 to 2011      ravens  0.383416  0.433891       0.321626  0.302132
# 11   2016 to 2017   cardinals  0.542256  0.428515       0.693348 -2.309591
# 384  2014 to 2015      eagles  0.291230  0.049891      -0.825062  0.706938
# 68   2013 to 2014    panthers -0.599165 -1.303598      -1.431763  0.926090
# 436  2006 to 2007  buccaneers -0.455160  0.455396      -0.483975 -0.770038
# 169  2009 to 2010     packers  1.774460  1.039442      -1.213420 -0.906586
# 123  2008 to 2009     cowboys  0.281595 -0.618788      -0.717122  1.053472
#
#      InteriorDLine       WRs       TEs  InteriorOLine   Tackles        QB  \
# 147       0.176749 -1.961223 -0.427315       0.270024 -0.233475  1.210933
# 36        0.684663 -0.264289 -0.602289      -1.629572  0.274676  0.374219
# 392      -0.226582 -0.527961 -0.761293      -1.760976  1.487118  0.805704
# 146      -0.036827 -0.265575 -1.084417       1.394737 -0.905211 -0.211524
# 35        0.830136  0.351870 -1.715147       1.024418 -0.577982  0.246832
# 11        0.323291 -0.813174 -0.308973      -0.005338  1.342148  0.825298
# 384       0.299359 -1.217264  0.036028      -0.943496  0.186292  2.034055
# 68        0.014885 -1.618021  1.560332      -1.389068 -0.075853 -0.120452
# 436       0.066061 -0.026239  0.188586      -0.103170  0.997762  2.016630
# 169       0.536202 -0.165958  0.248424      -0.436404  0.206739 -0.834522
# 123      -0.160827  1.408644 -0.599891      -0.329019  0.220701 -1.022495
#
#            RB   Special   Dead     IR  Prac  Susp  Wins  Playoff Wins  \
# 147 -1.335786  0.568758   0.06   3.84  0.00  0.00     1             0
# 36   1.181989 -0.764452   6.47   6.74 -0.18  0.00    -2             2
# 392  0.259714  0.305752  -2.30  -5.14  0.16  0.00     2             4
# 146 -0.927112  0.036056  -9.54   4.58  0.00  0.00    -4             0
# 35  -0.393522 -0.068776   2.87   0.65  0.23  0.00     0             1
# 11  -0.512846  0.960092  -4.25  15.91  0.03 -1.95     1             0
# 384  0.525128  0.658677   5.27  -4.86 -0.62  0.00    -3             0
# 68   0.354302 -0.732605 -14.19  -5.79  3.28  0.00    -5             0
# 436  0.126179 -0.544194  -0.47   6.81  4.97  0.00     5             0
# 169  0.022203  0.681242   0.10   6.25 -0.28  0.00    -1             4
# 123 -0.399199  0.238751  13.39  -7.62 -0.02  0.00     2             1
#
#      SuperBowl Win      Dist
# 147              0  2.581396
# 36               0  3.152850
# 392              0  3.158269
# 146              0  3.257890
# 35               0  3.309145
# 11               0  3.460349
# 384              0  3.512256
# 68               0  3.512465
# 436              0  3.583382
# 169              0  3.585836
# 123              0  3.601067
#                    Wins  Playoff Wins                           Recommendation
# Safeties       0.255710      0.737607       Increase spending in this position
# Corners        0.164385     -0.039871  No clear direction from historical data
# InsideBackers  0.018265     -0.463496  No clear direction from historical data
# Edge          -0.246578     -0.039871       Decrease spending in this position
# InteriorDLine -0.232879      0.119612  No clear direction from historical data
# WRs            0.397264      0.483431       Increase spending in this position
# TEs           -0.114156     -0.279094       Decrease spending in this position
# InteriorOLine  0.045663     -0.478448  No clear direction from historical data
# Tackles        0.607312      0.338900       Increase spending in this position
# QB             0.223747     -0.448545  No clear direction from historical data
# RB            -0.255710      0.294046  No clear direction from historical data
# Special        0.182650     -0.004984  No clear direction from historical data
# {'Sign':              AAV   Age  CapPerc     Dollars From           Player Position  \
#  2893    630000.0  26.0     0.36    630000.0  TEN     Curtis Riley       FS
#  2888    630000.0  24.0     0.36    630000.0  BUF      rey Coleman       WR
#  2889    630000.0  25.0     0.36    630000.0  PIT       Eli Rogers       WR
#  2887    705000.0  28.0     0.40    705000.0  ARI  Vinston Painter       RT
#  2877    720000.0  26.0     0.41    720000.0  CAR      Kaelin Clay       WR
#  ...          ...   ...      ...         ...  ...              ...      ...
#  2524   8500000.0  26.0     4.80  34000000.0  JAC      Marqise Lee       WR
#  2583   9600000.0  25.0     5.42   9600000.0  IND   Donte Moncrief       WR
#  2518  14000000.0  25.0     7.90  42000000.0  JAC   Allen Robinson       WR
#  2509  15500000.0  30.0     8.75  62000000.0   NE      Nate Solder       LT
#  2513  16000000.0  25.0     9.03  48000000.0  LAR    Sammy Watkins       WR
#
#         To    Year  Years
#  2893  NYG  2018.0    1.0
#  2888   NE  2018.0    1.0
#  2889  PIT  2018.0    1.0
#  2887  ARI  2018.0    1.0
#  2877  BUF  2018.0    1.0
#  ...   ...     ...    ...
#  2524  JAC  2018.0    4.0
#  2583  JAC  2018.0    1.0
#  2518  CHI  2018.0    3.0
#  2509  NYG  2018.0    4.0
#  2513   KC  2018.0    3.0
#
#  [93 rows x 10 columns],
#  'Cut':        CapPerc          Cash DeadCap IR               Player Position Prac  \
#  13785     0.66     $850,000        0  0      Angelo Blackson       DE    0
#  2866      7.11  $12,306,000        0  0     Jadeveon Clowney      OLB    0
#  2662      8.01  $11,000,000        0  0            J.J. Watt       DE    0
#  34235     0.01      $15,200        1  0     Kennan Gilchrist      OLB    0
#  35185     0.00             -       1  0         Mason Gentry       DE    0
#  ...        ...           ...     ... ..                  ...      ...  ...
#  19130     0.39     $705,000        0  0  Christian Covington       DE    0
#  35935     0.00       $7,600        1  0        Chris Landrum      OLB    0
#  35936     0.00       $7,600        1  0        MyCole Pruitt       TE    0
#  17894     0.42     $790,000        0  0         Brandon Dunn       DE    0
#  30891     0.05      $91,200        1  0         Jerell Adams       TE    0
#
#        SalaryCap Susp    Team  Year
#  13785   1240000    0  texans  2018
#  2866   13311000    0  texans  2018
#  2662   15000000    0  texans  2018
#  34235     15200    0  texans  2018
#  35185      1666    0  texans  2018
#  ...         ...  ...     ...   ...
#  19130    727622    0  texans  2018
#  35935      7600    0  texans  2018
#  35936      7600    0  texans  2018
#  17894    790000    0  texans  2018
#  30891     91200    0  texans  2018
#
#  [32 rows x 11 columns]}

# %%
# Out:
# {2009: 123000000,
#  2011: 120000000,
#  2012: 120600000,
#  2013: 123000000,
#  2014: 133000000,
#  2015: 143280000,
#  2016: 155270000,
#  2017: 167000000,
#  2018: 177200000,
#  2019: 188200000,
#  2020: 198200000}

# %% [markdown]
# The teams most similar to the 2018 Texans (that aren't the Texans or in the future) are the 2017 Broncos (5 Wins), the 2011 Ravens (12 Wins), and the 2007 Steelers (10 Wins).

# %% [markdown]
# # Quickly break down a few examples one-by-one

# %% [markdown]
# ### 2017 Broncos (5 Wins)

# %%
TopTeams = Df.sort_values(by = "Dist")[:1]

NextYear = Df[(Df['Team'] == TopTeams.iloc[0,1])&(Df['Year'] == TopTeams.iloc[0,0]+1)]

Result = NextYear.copy()

Groups2 = Groups.copy()
Groups2.extend(['Dead','IR','Prac','Susp','Wins','Playoff Wins'])
for i in range(0,len(Groups2)):
    Position = Groups2[i]
    NewVal = NextYear[Position].values - TopTeams[Position].values
    Result.iloc[0,i+2] = NewVal
    
Result.iloc[0,0] = '2017 to 2018'
Result
# Out:
#              Year     Team  Safeties   Corners  InsideBackers      Edge  InteriorDLine       WRs       TEs  InteriorOLine   Tackles        QB        RB   Special  Dead    IR  Prac  Susp  Wins  Playoff Wins  SuperBowl Win   Dist
# 148  2017 to 2018  broncos -0.227726 -0.221059       0.485421 -0.923957       0.176749 -1.961223 -0.427315       0.270024 -0.233475  1.210933 -1.335786  0.568758  0.06  3.84   0.0   0.0     1             0              0  100.0

# %% [markdown]
# #### The 2018 Broncos spent considerably less on WRs, Edge Rushers, and RBs, while spending considerably more on their QB, which ultimately only led to a 1-win improvement

# %%
TopTeams = Df.sort_values(by = "Dist")[1:2]

NextYear = Df[(Df['Team'] == TopTeams.iloc[0,1])&(Df['Year'] == TopTeams.iloc[0,0]+1)]

Result2 = NextYear.copy()

for i in range(0,len(Groups2)):
    Position = Groups2[i]
    NewVal = NextYear[Position].values - TopTeams[Position].values
    Result2.iloc[0,i+2] = NewVal
    
Result2.iloc[0,0] = str(TopTeams['Year'].values[0]) + " to " +  str(NextYear['Year'].values[0])
Result2
# Out:
#             Year    Team  Safeties   Corners  InsideBackers      Edge  InteriorDLine       WRs       TEs  InteriorOLine   Tackles        QB        RB   Special  Dead    IR  Prac  Susp  Wins  Playoff Wins  SuperBowl Win      Dist
# 37  2011 to 2012  ravens  0.500458 -0.311136       0.253507 -0.906201       0.684663 -0.264289 -0.602289      -1.629572  0.274676  0.374219  1.181989 -0.764452  6.47  6.74 -0.18   0.0    -2             2              1  3.949323

# %% [markdown]
# #### The 2012 Ravens spend much less on Interior Offensive Line and Edge and much more on RB and Interior Defensive Line. The 2012 offseason saw the Ravens lose G Ben Grubbs and DE/NT Cory Redding and drafting future all-pros in Courtney Upshaw and Kelechi Osemele. The Ravens also re-signed RB Ray Rice to a large deal and Interior D-Lineman Haloti Ngata's contract value increased significantly. This ultimately led to fewer regular season wins, but a Super Bowl Win

# %%
ChangeFrame = pd.DataFrame()
for j in range(0,11):
    TopTeams = Df.sort_values(by = "Dist")[j:j+1]

    NextYear = Df[(Df['Team'] == TopTeams.iloc[0,1])&(Df['Year'] == TopTeams.iloc[0,0]+1)]

    Result2 = NextYear.copy()

    for i in range(0,len(Groups2)):
        Position = Groups2[i]
        NewVal = NextYear[Position].values - TopTeams[Position].values
        Result2.iloc[0,i+2] = NewVal

    Result2.iloc[0,0] = str(TopTeams['Year'].values[0]) + " to " +  str(NextYear['Year'].values[0])
    ChangeFrame = ChangeFrame.append(Result2)

display(ChangeFrame)
    
X = ChangeFrame.copy()

cor = X.corr()
sns.heatmap(cor, xticklabels=cor.columns,yticklabels=cor.columns)
cor[['Wins','Playoff Wins','SuperBowl Win']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-365-4a7961161ce7> in <module>
#       1 ChangeFrame = pd.DataFrame()
#       2 for j in range(0,11):
# ----> 3     TopTeams = Df.sort_values(by = "Dist")[j:j+1]
#       4
#       5     NextYear = Df[(Df['Team'] == TopTeams.iloc[0,1])&(Df['Year'] == TopTeams.iloc[0,0]+1)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4991
#    4992             by = by[0]
# -> 4993             k = self._get_label_or_level_values(by, axis=axis)
#    4994
#    4995             if isinstance(ascending, (tuple, list)):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1772             values = self.axes[axis].get_level_values(key)._values
#    1773         else:
# -> 1774             raise KeyError(key)
#    1775
#    1776         # Check for duplicates
#
# KeyError: 'Dist'

# %%
FA
# Out:
#              AAV   Age  CapPerc     Dollars From            Player Position  \
# 0     12666667.0  25.0    10.52  76000000.0  CAR   Charles Johnson       DE
# 1     12000000.0  30.0     9.97  60000000.0  OAK   Nnamdi Asomugha       CB
# 2      7571429.0  27.0     6.29  53000000.0   TB      Davin Joseph        G
# 3      9750000.0  27.0     8.10  48750000.0  CIN     nathan Joseph       CB
# 4      9000000.0  27.0     7.48  45000000.0  NYJ   Santonio Holmes       WR
# ...          ...   ...      ...         ...  ...               ...      ...
# 3290    645000.0  26.0     0.34    645000.0  ATL       Marvin Hall       WR
# 3291    570000.0  26.0     0.30    570000.0  NYG   Jordan Williams       LB
# 3292    570000.0  25.0     0.30    570000.0   GB     Nico Siragusa        G
# 3293    570000.0  26.0     0.30    570000.0  IND  DeShawn Williams       DT
# 3294    500000.0  27.0     0.27    500000.0  MIN      Cedrick Lang        T
#
#        To    Year  Years
# 0     CAR  2011.0    6.0
# 1     PHI  2011.0    5.0
# 2      TB  2011.0    7.0
# 3     HOU  2011.0    5.0
# 4     NYJ  2011.0    5.0
# ...   ...     ...    ...
# 3290  CHI  2019.0    1.0
# 3291  TEN  2019.0    1.0
# 3292  IND  2019.0    1.0
# 3293  DEN  2019.0    1.0
# 3294   NE  2019.0    1.0
#
# [3295 rows x 10 columns]

# %%
# Out:
#      Unnamed: 0  Year       Team  CapRoom
# 0             0  2005  cardinals    35.43
# 1             1  2006  cardinals    17.89
# 2             2  2007  cardinals    28.35
# 3             3  2008  cardinals    14.77
# 4             4  2009  cardinals     6.41
# ..          ...   ...        ...      ...
# 475         475  2015   redskins     5.67
# 476         476  2016   redskins    20.11
# 477         477  2017   redskins     8.16
# 478         478  2018   redskins    11.54
# 479         479  2019   redskins    13.77
#
# [480 rows x 4 columns]
