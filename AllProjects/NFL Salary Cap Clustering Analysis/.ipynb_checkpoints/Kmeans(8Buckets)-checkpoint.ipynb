# %%
import pandas as pd
import sklearn as sk
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
Df3 = pd.read_csv('3Buckets.csv')
Df5 = pd.read_csv('5Buckets.csv')
Df8 = pd.read_csv('8Buckets.csv')
Df12 = pd.read_csv('12Buckets.csv')

# %%
## Test if normalization by year affects the analysis
labels = ['Dbacks','LineBackers','Dline','PassCatchers','Oline','QB','RB','Special']
Df8Normalized = Df8.copy()

def Normalize(x):
    RetList = []
    for label in labels:
        dfyear = Df8Normalized[Df8Normalized['Year'] == x['Year']]
        val = (x[label] - np.mean(dfyear[label]))/(np.std(dfyear[label]))
        
        RetList.append(val)
    
    return pd.Series(RetList)
    
    
    
Df8Normalized[['Dbacks','LineBackers','Dline','PassCatchers','Oline','QB','RB','Special']] = Df8Normalized.apply(Normalize, axis = 1)

# %%
X = Df8[['Dbacks','LineBackers','Dline','PassCatchers','Oline','QB','RB','Special']]
NonPredictorX = Df8[['Year','Team']]
Y = Df8[['Wins', 'Playoff Wins', 'SuperBowl Win']]

X_Norm = Df8Normalized[['Dbacks','LineBackers','Dline','PassCatchers','Oline','QB','RB','Special']]
NonPredictorX_Norm = Df8Normalized[['Year','Team']]
Y_Norm = Df8Normalized[['Wins', 'Playoff Wins', 'SuperBowl Win']]

# %%
## Elbow Plot
models = []
wcss = []
for i in range(1,15): 
    i = int(i)
    KM = KMeans(n_clusters = i, random_state = 0, init = "k-means++", n_init = 10)
    KM.fit(X)
    wcss.append(KM.inertia_)
    
plt.plot(range(1,15),wcss)
plt.title("Elbow Plot")
plt.xlabel("Num Clusters")
plt.ylabel("Within Cluster Sum of Squares")

plt.show()
print("Seemingly the best number of clusters is 7, will try between 6-8")
# Out:
# Seemingly the best number of clusters is 7, will try between 6-8

# %% [markdown]
# ### 6 Clusters (Not Normalized)

# %%
## 3 clusters
KM8_6 = KMeans(n_clusters = 6, random_state = 0, init = "k-means++", n_init = 100)
KM8_6.fit(X)
Df8_6Clust = Df8.copy()
Df8_6Clust['Cluster'] = KM8_6.labels_
KM8_6.cluster_centers_
# Out:
# array([[12.81      ,  8.91195122, 22.85987805, 14.74256098, 15.45012195,
#          7.51353659,  5.40012195,  2.69560976],
#        [16.1121875 , 17.89484375,  7.4821875 , 14.9215625 , 14.15078125,
#         13.36671875,  4.4709375 ,  2.85265625],
#        [ 8.52365385,  7.1975    ,  9.48778846,  8.70163462,  8.21932692,
#          7.46259615,  4.95865385,  1.72865385],
#        [10.98752941,  8.73929412, 11.73929412, 14.82670588, 17.746     ,
#         10.93270588,  4.51776471,  2.57388235],
#        [17.42355556, 15.82777778, 12.21677778, 14.98822222, 16.02177778,
#          5.83533333,  5.19288889,  3.08011111],
#        [19.678     ,  9.66254545, 16.756     , 12.78890909, 15.50145455,
#         12.10581818,  4.66272727,  2.89763636]])

# %%
##Match Averages spending back to groupby to gain cluster averages for all metrics
Df8_6_GB = Df8_6Clust.groupby(by = "Cluster")[['SuperBowl Win', "Playoff Wins",'Wins']].mean()
Df8_6_GB.reset_index(inplace = True)
labs = X.columns
# for lab in labs:
#     Df5_3_GB[lab] = 0

for i in range (0,len(KM8_6.cluster_centers_)):
    k_m = 0
    for lab in labs:
        val = KM8_6.cluster_centers_[i][k_m]
        Df8_6_GB.set_value(i,lab,val)
        k_m+=1
        
Df8_6_GB['TotCap'] = Df8_6_GB['Dbacks'] + Df8_6_GB['LineBackers'] + Df8_6_GB['Dline'] + Df8_6_GB['PassCatchers'] + Df8_6_GB['Oline'] + Df8_6_GB['QB'] + Df8_6_GB['RB'] + Df8_6_GB['Special']
Df8_6_GB['Count'] = Df8_6Clust.groupby(by = "Cluster")['Year'].count()
Df8_6_GB
# Out:
# C:\Users\blueh\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if sys.path[0] == '':
#    Cluster  SuperBowl Win  Playoff Wins      Wins     Dbacks  LineBackers  \
# 0        0       0.012195      0.365854  7.792683  12.810000     8.911951
# 1        1       0.062500      0.718750  9.109375  16.112188    17.894844
# 2        2       0.028846      0.432692  7.740385   8.523654     7.197500
# 3        3       0.023529      0.376471  7.435294  10.987529     8.739294
# 4        4       0.022222      0.411111  8.100000  17.423556    15.827778
# 5        5       0.036364      0.581818  8.054545  19.678000     9.662545
#
#        Dline  PassCatchers      Oline         QB        RB   Special  TotCap  \
# 0  22.859878     14.742561  15.450122   7.513537  5.400122  2.695610   64.57
# 1   7.482188     14.921563  14.150781  13.366719  4.470937  2.852656   82.11
# 2   9.487788      8.701635   8.219327   7.462596  4.958654  1.728654   71.65
# 3  11.739294     14.826706  17.746000  10.932706  4.517765  2.573882   85.23
# 4  12.216778     14.988222  16.021778   5.835333  5.192889  3.080111   93.59
# 5  16.756000     12.788909  15.501455  12.105818  4.662727  2.897636   74.78
#
#    Count
# 0     82
# 1     64
# 2    104
# 3     85
# 4     90
# 5     55

# %%
## Calculate Average Prediction Error
for i in range(0,3):
    Df8_6Clust[i] = 0

def DistFunc(x):
    D0 = np.sqrt((x['Dbacks']-Df8_6_GB.iat[0,4])**2+(x['LineBackers'] - Df8_6_GB.iat[0,5])**2 + (x['Dline'] - Df8_6_GB.iat[0,6])**2
                +(x['PassCatchers']-Df8_6_GB.iat[0,7])**2+(x['Oline']-Df8_6_GB.iat[0,8])**2+(x['QB']-Df8_6_GB.iat[0,9])**2
                +(x['RB']-Df8_6_GB.iat[0,10])**2+(x['Special']-Df8_6_GB.iat[0,11])**2)
    
    D1 = np.sqrt((x['Dbacks']-Df8_6_GB.iat[1,4])**2+(x['LineBackers'] - Df8_6_GB.iat[1,5])**2 + (x['Dline'] - Df8_6_GB.iat[1,6])**2
                +(x['PassCatchers']-Df8_6_GB.iat[1,7])**2+(x['Oline']-Df8_6_GB.iat[1,8])**2+(x['QB']-Df8_6_GB.iat[1,9])**2
                +(x['RB']-Df8_6_GB.iat[1,10])**2+(x['Special']-Df8_6_GB.iat[1,11])**2)
    
    D2 = np.sqrt((x['Dbacks']-Df8_6_GB.iat[2,4])**2+(x['LineBackers'] - Df8_6_GB.iat[2,5])**2 + (x['Dline'] - Df8_6_GB.iat[2,6])**2
                +(x['PassCatchers']-Df8_6_GB.iat[2,7])**2+(x['Oline']-Df8_6_GB.iat[2,8])**2+(x['QB']-Df8_6_GB.iat[2,9])**2
                +(x['RB']-Df8_6_GB.iat[2,10])**2+(x['Special']-Df8_6_GB.iat[2,11])**2)
    
    D3 = np.sqrt((x['Dbacks']-Df8_6_GB.iat[3,4])**2+(x['LineBackers'] - Df8_6_GB.iat[3,5])**2 + (x['Dline'] - Df8_6_GB.iat[3,6])**2
                +(x['PassCatchers']-Df8_6_GB.iat[3,7])**2+(x['Oline']-Df8_6_GB.iat[3,8])**2+(x['QB']-Df8_6_GB.iat[3,9])**2
                +(x['RB']-Df8_6_GB.iat[3,10])**2+(x['Special']-Df8_6_GB.iat[3,11])**2)
    
    D4 = np.sqrt((x['Dbacks']-Df8_6_GB.iat[4,4])**2+(x['LineBackers'] - Df8_6_GB.iat[4,5])**2 + (x['Dline'] - Df8_6_GB.iat[4,6])**2
                +(x['PassCatchers']-Df8_6_GB.iat[4,7])**2+(x['Oline']-Df8_6_GB.iat[4,8])**2+(x['QB']-Df8_6_GB.iat[4,9])**2
                +(x['RB']-Df8_6_GB.iat[4,10])**2+(x['Special']-Df8_6_GB.iat[4,11])**2)
    
    D5 = np.sqrt((x['Dbacks']-Df8_6_GB.iat[5,4])**2+(x['LineBackers'] - Df8_6_GB.iat[5,5])**2 + (x['Dline'] - Df8_6_GB.iat[5,6])**2
                +(x['PassCatchers']-Df8_6_GB.iat[5,7])**2+(x['Oline']-Df8_6_GB.iat[5,8])**2+(x['QB']-Df8_6_GB.iat[5,9])**2
                +(x['RB']-Df8_6_GB.iat[5,10])**2+(x['Special']-Df8_6_GB.iat[5,11])**2)
    
    Tot = D0 + D1 + D2 + D3 + D4 + D5
    
    N0 = 1/((D0/Tot))
    N1 = 1/((D1/Tot))
    N2 = 1/((D2/Tot))
    N3 = 1/((D3/Tot))
    N4 = 1/((D4/Tot))
    N5 = 1/((D5/Tot))
    TotN = N0 + N1 + N2 + N3 + N4 + N5
    
    Perc0 = N0/TotN*100
    Perc1 = N1/TotN*100
    Perc2 = N2/TotN*100
    Perc3 = N3/TotN*100
    Perc4 = N4/TotN*100
    Perc5 = N5/TotN*100
    
    return pd.Series([Perc0,Perc1,Perc2,Perc3,Perc4,Perc5])

def ExpectedWins(x):
    WinShares0 = x[0]/100*Df8_6_GB.iat[0,3]
    WinShares1 = x[1]/100*Df8_6_GB.iat[1,3]
    WinShares2 = x[2]/100*Df8_6_GB.iat[2,3]
    WinShares3 = x[3]/100*Df8_6_GB.iat[3,3]
    WinShares4 = x[4]/100*Df8_6_GB.iat[4,3]
    WinShares5 = x[5]/100*Df8_6_GB.iat[5,3]
    ExpWins = WinShares0 + WinShares1 + WinShares2 + WinShares3 + WinShares4 + WinShares5
    return ExpWins

Df8_6Clust[[0,1,2,3,4,5]] = Df8_6Clust.apply(DistFunc, axis = 1)
    
Df8_6Clust['ExpWins'] = Df8_6Clust.apply(ExpectedWins, axis = 1)
Df8_6Clust['Error'] = abs(Df8_6Clust['Wins'] - Df8_6Clust['ExpWins'])
AvgError = sum(Df8_6Clust['Error'])/len(Df8_6Clust)

# %%
AvgError
# Out:
# 2.54518296166546

# %%
Df8_6_GB
# Out:
#    Cluster  SuperBowl Win  Playoff Wins      Wins     Dbacks  LineBackers  \
# 0        0       0.012195      0.365854  7.792683  12.810000     8.911951
# 1        1       0.062500      0.718750  9.109375  16.112188    17.894844
# 2        2       0.028846      0.432692  7.740385   8.523654     7.197500
# 3        3       0.023529      0.376471  7.435294  10.987529     8.739294
# 4        4       0.022222      0.411111  8.100000  17.423556    15.827778
# 5        5       0.036364      0.581818  8.054545  19.678000     9.662545
#
#        Dline  PassCatchers      Oline         QB        RB   Special  TotCap  \
# 0  22.859878     14.742561  15.450122   7.513537  5.400122  2.695610   64.57
# 1   7.482188     14.921563  14.150781  13.366719  4.470937  2.852656   82.11
# 2   9.487788      8.701635   8.219327   7.462596  4.958654  1.728654   71.65
# 3  11.739294     14.826706  17.746000  10.932706  4.517765  2.573882   85.23
# 4  12.216778     14.988222  16.021778   5.835333  5.192889  3.080111   93.59
# 5  16.756000     12.788909  15.501455  12.105818  4.662727  2.897636   74.78
#
#    Count
# 0     82
# 1     64
# 2    104
# 3     85
# 4     90
# 5     55

# %% [markdown]
# ## 6 Clusters (Normalized)

# %%
## 3 clusters
KM8_6 = KMeans(n_clusters = 6, random_state = 0, init = "k-means++", n_init = 100)
KM8_6.fit(X_Norm)
Df8_6Clust = Df8Normalized.copy()
Df8_6Clust['Cluster'] = KM8_6.labels_
KM8_6.cluster_centers_
# Out:
# array([[ 0.83511894, -0.35091461, -0.13491462, -0.15204662,  0.13362485,
#         -0.0502736 , -0.11662242,  1.37007395],
#        [-0.50564315, -0.14665444,  0.18689298, -0.33992015,  0.72434319,
#         -0.46457981,  1.40734817, -0.3251466 ],
#        [-0.06836384, -0.67473695,  1.16777878,  0.07575758, -0.40451716,
#         -0.07518225, -0.1564212 , -0.37808939],
#        [-0.62554645,  0.07585124, -0.37946087, -0.88131969, -0.21308184,
#          0.40505373, -0.28150956, -0.19911749],
#        [ 1.04433018,  1.22264238, -0.66854322, -0.01141069, -0.46491428,
#         -0.40062193, -0.23798291, -0.44968123],
#        [-0.45444473,  0.18212586, -0.53716521,  1.24236493,  0.31767027,
#          0.4834788 , -0.4951825 ,  0.09012528]])

# %%
##Match Averages spending back to groupby to gain cluster averages for all metrics
Df8_6_GB = Df8_6Clust.groupby(by = "Cluster")[['SuperBowl Win', "Playoff Wins",'Wins']].mean()
Df8_6_GB.reset_index(inplace = True)
labs = X.columns
# for lab in labs:
#     Df5_3_GB[lab] = 0

for i in range (0,len(KM8_6.cluster_centers_)):
    k_m = 0
    for lab in labs:
        val = KM8_6.cluster_centers_[i][k_m]
        Df8_6_GB.set_value(i,lab,val)
        k_m+=1
        
Df8_6_GB['TotCap'] = Df8['Dbacks'] + Df8['LineBackers'] + Df8['Dline'] + Df8['PassCatchers'] + Df8['Oline'] + Df8['QB'] + Df8['RB'] + Df8['Special']
Df8_6_GB['Count'] = Df8_6Clust.groupby(by = "Cluster")['Year'].count()
Df8_6_GB
# Out:
# C:\Users\blueh\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if sys.path[0] == '':
#    Cluster  SuperBowl Win  Playoff Wins      Wins    Dbacks  LineBackers  \
# 0        0       0.013514      0.459459  7.783784  0.835119    -0.350915
# 1        1       0.013514      0.459459  8.081081 -0.505643    -0.146654
# 2        2       0.020000      0.390000  7.670000 -0.068364    -0.674737
# 3        3       0.012195      0.365854  7.536585 -0.625546     0.075851
# 4        4       0.044118      0.514706  8.779412  1.044330     1.222642
# 5        5       0.073171      0.609756  8.231707 -0.454445     0.182126
#
#       Dline  PassCatchers     Oline        QB        RB   Special  TotCap  \
# 0 -0.134915     -0.152047  0.133625 -0.050274 -0.116622  1.370074   64.57
# 1  0.186893     -0.339920  0.724343 -0.464580  1.407348 -0.325147   82.11
# 2  1.167779      0.075758 -0.404517 -0.075182 -0.156421 -0.378089   71.65
# 3 -0.379461     -0.881320 -0.213082  0.405054 -0.281510 -0.199117   85.23
# 4 -0.668543     -0.011411 -0.464914 -0.400622 -0.237983 -0.449681   93.59
# 5 -0.537165      1.242365  0.317670  0.483479 -0.495182  0.090125   74.78
#
#    Count
# 0     74
# 1     74
# 2    100
# 3     82
# 4     68
# 5     82

# %%
## Calculate Average Prediction Error
for i in range(0,3):
    Df8_6Clust[i] = 0

def DistFunc(x):
    D0 = np.sqrt((x['Dbacks']-Df8_6_GB.iat[0,4])**2+(x['LineBackers'] - Df8_6_GB.iat[0,5])**2 + (x['Dline'] - Df8_6_GB.iat[0,6])**2
                +(x['PassCatchers']-Df8_6_GB.iat[0,7])**2+(x['Oline']-Df8_6_GB.iat[0,8])**2+(x['QB']-Df8_6_GB.iat[0,9])**2
                +(x['RB']-Df8_6_GB.iat[0,10])**2+(x['Special']-Df8_6_GB.iat[0,11])**2)
    
    D1 = np.sqrt((x['Dbacks']-Df8_6_GB.iat[1,4])**2+(x['LineBackers'] - Df8_6_GB.iat[1,5])**2 + (x['Dline'] - Df8_6_GB.iat[1,6])**2
                +(x['PassCatchers']-Df8_6_GB.iat[1,7])**2+(x['Oline']-Df8_6_GB.iat[1,8])**2+(x['QB']-Df8_6_GB.iat[1,9])**2
                +(x['RB']-Df8_6_GB.iat[1,10])**2+(x['Special']-Df8_6_GB.iat[1,11])**2)
    
    D2 = np.sqrt((x['Dbacks']-Df8_6_GB.iat[2,4])**2+(x['LineBackers'] - Df8_6_GB.iat[2,5])**2 + (x['Dline'] - Df8_6_GB.iat[2,6])**2
                +(x['PassCatchers']-Df8_6_GB.iat[2,7])**2+(x['Oline']-Df8_6_GB.iat[2,8])**2+(x['QB']-Df8_6_GB.iat[2,9])**2
                +(x['RB']-Df8_6_GB.iat[2,10])**2+(x['Special']-Df8_6_GB.iat[2,11])**2)
    
    D3 = np.sqrt((x['Dbacks']-Df8_6_GB.iat[3,4])**2+(x['LineBackers'] - Df8_6_GB.iat[3,5])**2 + (x['Dline'] - Df8_6_GB.iat[3,6])**2
                +(x['PassCatchers']-Df8_6_GB.iat[3,7])**2+(x['Oline']-Df8_6_GB.iat[3,8])**2+(x['QB']-Df8_6_GB.iat[3,9])**2
                +(x['RB']-Df8_6_GB.iat[3,10])**2+(x['Special']-Df8_6_GB.iat[3,11])**2)
    
    D4 = np.sqrt((x['Dbacks']-Df8_6_GB.iat[4,4])**2+(x['LineBackers'] - Df8_6_GB.iat[4,5])**2 + (x['Dline'] - Df8_6_GB.iat[4,6])**2
                +(x['PassCatchers']-Df8_6_GB.iat[4,7])**2+(x['Oline']-Df8_6_GB.iat[4,8])**2+(x['QB']-Df8_6_GB.iat[4,9])**2
                +(x['RB']-Df8_6_GB.iat[4,10])**2+(x['Special']-Df8_6_GB.iat[4,11])**2)
    
    D5 = np.sqrt((x['Dbacks']-Df8_6_GB.iat[5,4])**2+(x['LineBackers'] - Df8_6_GB.iat[5,5])**2 + (x['Dline'] - Df8_6_GB.iat[5,6])**2
                +(x['PassCatchers']-Df8_6_GB.iat[5,7])**2+(x['Oline']-Df8_6_GB.iat[5,8])**2+(x['QB']-Df8_6_GB.iat[5,9])**2
                +(x['RB']-Df8_6_GB.iat[5,10])**2+(x['Special']-Df8_6_GB.iat[5,11])**2)
    
    Tot = D0 + D1 + D2 + D3 + D4 + D5
    
    N0 = 1/((D0/Tot))
    N1 = 1/((D1/Tot))
    N2 = 1/((D2/Tot))
    N3 = 1/((D3/Tot))
    N4 = 1/((D4/Tot))
    N5 = 1/((D5/Tot))
    TotN = N0 + N1 + N2 + N3 + N4 + N5
    
    Perc0 = N0/TotN*100
    Perc1 = N1/TotN*100
    Perc2 = N2/TotN*100
    Perc3 = N3/TotN*100
    Perc4 = N4/TotN*100
    Perc5 = N5/TotN*100
    
    return pd.Series([Perc0,Perc1,Perc2,Perc3,Perc4,Perc5])

def ExpectedWins(x):
    WinShares0 = x[0]/100*Df8_6_GB.iat[0,3]
    WinShares1 = x[1]/100*Df8_6_GB.iat[1,3]
    WinShares2 = x[2]/100*Df8_6_GB.iat[2,3]
    WinShares3 = x[3]/100*Df8_6_GB.iat[3,3]
    WinShares4 = x[4]/100*Df8_6_GB.iat[4,3]
    WinShares5 = x[5]/100*Df8_6_GB.iat[5,3]
    ExpWins = WinShares0 + WinShares1 + WinShares2 + WinShares3 + WinShares4 + WinShares5
    return ExpWins

Df8_6Clust[[0,1,2,3,4,5]] = Df8_6Clust.apply(DistFunc, axis = 1)
    
Df8_6Clust['ExpWins'] = Df8_6Clust.apply(ExpectedWins, axis = 1)
Df8_6Clust['Error'] = abs(Df8_6Clust['Wins'] - Df8_6Clust['ExpWins'])
AvgError = sum(Df8_6Clust['Error'])/len(Df8_6Clust)

# %%
AvgError
# Out:
# 2.546147567706773

# %% [markdown]
# Standardizing by year does not have much of an effect on average error. Maybe it will in future iterations

# %% [markdown]
# ## For the Fun of it, 12 clusters

# %%
## 12 clusters
KM8_20 = KMeans(n_clusters = 40, random_state = 0, init = "k-means++", n_init = 100)
KM8_20.fit(X)
Df8_20Clust = Df8.copy()
Df8_20Clust['Cluster'] = KM8_20.labels_
KM8_20.cluster_centers_
# Out:
# array([[16.521     ,  4.44      ,  6.766     , 13.258     ,  6.519     ,
#          5.159     ,  2.868     ,  1.938     ],
#        [ 8.39222222, 13.19888889, 22.36444444, 14.75222222, 14.28222222,
#         10.31555556,  4.59222222,  2.81444444],
#        [10.55266667, 11.74533333, 10.27533333, 11.62933333, 15.21266667,
#         13.144     ,  3.06933333,  2.43466667],
#        [19.0575    , 15.9135    , 10.427     , 18.488     , 13.7345    ,
#          5.7705    ,  4.7965    ,  2.9265    ],
#        [13.56923077,  7.18461538, 11.72153846,  6.15461538,  8.76076923,
#         10.32769231,  3.94692308,  1.87769231],
#        [18.80866667,  9.27733333, 13.81666667, 14.176     , 19.25933333,
#          4.63933333,  4.236     ,  2.08133333],
#        [15.74958333,  7.11625   , 22.375     , 12.96      , 16.81166667,
#          7.17208333,  4.74833333,  2.45541667],
#        [10.2925    , 14.19      , 17.68125   , 16.3025    , 26.6       ,
#          4.51125   ,  5.42375   ,  3.2625    ],
#        [17.27611111, 15.71277778, 11.41777778,  9.40277778, 17.905     ,
#          6.32388889,  4.99777778,  2.86277778],
#        [ 3.47363636,  6.72818182,  8.51272727,  8.02272727,  5.87      ,
#          2.19181818,  6.52363636,  1.45545455],
#        [16.045     , 12.052     , 20.464     , 12.896     ,  7.95      ,
#          6.397     ,  7.963     ,  4.489     ],
#        [13.55818182,  7.01090909, 17.93363636, 21.22636364, 13.36363636,
#         12.90636364,  4.12      ,  2.45363636],
#        [18.39      ,  9.664     , 18.442     , 12.096     , 14.69666667,
#         13.808     ,  4.562     ,  2.80066667],
#        [22.7425    , 21.54125   , 14.705     , 15.075     , 14.20875   ,
#          6.8775    ,  6.42625   ,  3.855     ],
#        [17.2625    , 22.93      ,  8.41833333, 12.25083333, 17.55083333,
#         12.24416667,  3.7675    ,  2.20083333],
#        [ 7.7       ,  9.082     ,  4.826     , 10.087     , 12.839     ,
#          4.135     ,  3.721     ,  2.055     ],
#        [17.33153846,  8.48      , 11.87076923, 13.71230769, 21.40769231,
#         13.38769231,  3.92846154,  2.76      ],
#        [10.57      , 11.16416667, 13.66416667, 14.78083333, 13.36583333,
#         13.61666667,  8.52916667,  3.09166667],
#        [20.42714286, 22.36      ,  6.32285714, 17.47285714, 10.77142857,
#         14.75714286,  4.49428571,  2.58428571],
#        [12.05      , 14.078     , 12.73      , 17.21133333, 14.618     ,
#          6.97266667,  3.43733333,  2.76066667],
#        [ 5.52733333, 11.816     ,  9.65533333,  7.476     ,  9.41866667,
#          9.25866667,  7.73133333,  1.24333333],
#        [12.758     , 11.944     ,  6.949     , 14.642     , 20.963     ,
#          5.622     ,  6.808     ,  2.816     ],
#        [26.28166667, 10.40833333, 16.455     ,  9.86      , 17.15166667,
#          8.54166667,  4.15      ,  3.34166667],
#        [ 9.27      ,  7.20833333, 15.7       , 19.06166667, 19.60166667,
#         13.21416667,  3.29916667,  2.48833333],
#        [14.30733333, 18.22      , 15.40666667, 12.20933333, 12.93266667,
#          9.38866667,  4.55      ,  3.29666667],
#        [17.66444444, 13.82111111,  6.80166667, 14.23611111, 16.94777778,
#         14.50277778,  3.86333333,  3.63944444],
#        [ 5.87      , 11.51      ,  6.59666667, 24.        ,  7.99666667,
#          8.01666667,  3.41666667,  2.61      ],
#        [11.024     ,  7.524     , 24.513     , 19.96      , 18.049     ,
#          4.788     ,  4.441     ,  2.889     ],
#        [11.08571429, 16.48571429,  7.30285714, 10.84      , 11.14428571,
#         13.50714286,  7.53571429,  2.05428571],
#        [ 8.21      ,  7.75615385, 14.32230769,  6.80692308,  6.72076923,
#          4.59230769,  3.86230769,  2.18384615],
#        [15.08333333, 11.82416667, 17.61833333, 16.39166667, 16.81333333,
#          6.61666667,  6.35833333,  2.63916667],
#        [18.545     , 19.925     ,  3.2125    , 10.75      ,  3.81      ,
#          5.545     ,  5.7075    ,  0.51      ],
#        [12.92666667, 16.652     ,  7.59266667, 20.32666667, 15.95933333,
#         13.148     ,  3.43      ,  2.74733333],
#        [10.45923077,  6.91461538, 25.73153846, 10.92384615, 13.18769231,
#          5.33538462,  6.92461538,  2.79230769],
#        [21.79083333,  9.95916667, 11.225     , 16.76333333, 11.60416667,
#         11.16083333,  5.8975    ,  3.06083333],
#        [11.13846154,  6.72076923, 13.07538462, 10.00692308, 22.04      ,
#          9.72846154,  5.11384615,  2.69923077],
#        [ 6.01933333,  3.40133333,  7.50266667,  8.10333333,  6.478     ,
#         10.48466667,  3.22466667,  2.01133333],
#        [ 5.9       ,  3.7925    ,  3.6       , 17.595     , 11.69      ,
#          8.02      ,  8.64      ,  1.14      ],
#        [10.9205    ,  5.073     , 12.373     , 10.478     , 12.2505    ,
#          9.731     ,  5.0635    ,  1.843     ],
#        [18.42285714,  9.95857143, 26.03714286, 12.94714286, 13.47428571,
#         16.25142857,  5.27428571,  2.97428571]])

# %%
##Match Averages spending back to groupby to gain cluster averages for all metrics
Df8_20_GB = Df8_20Clust.groupby(by = "Cluster")[['SuperBowl Win', "Playoff Wins",'Wins']].mean()
Df8_20_GB.reset_index(inplace = True)
labs = X.columns
# for lab in labs:
#     Df5_3_GB[lab] = 0

for i in range (0,len(KM8_20.cluster_centers_)):
    k_m = 0
    for lab in labs:
        val = KM8_20.cluster_centers_[i][k_m]
        Df8_20_GB.set_value(i,lab,val)
        k_m+=1
        
Df8_20_GB['TotCap'] = Df8_20_GB['Dbacks'] + Df8_20_GB['LineBackers'] + Df8_20_GB['Dline'] + Df8_20_GB['PassCatchers'] + Df8_20_GB['Oline'] + Df8_20_GB['QB'] + Df8_20_GB['RB'] + Df8_20_GB['Special']
Df8_20_GB['Count'] = Df8_20Clust.groupby(by = "Cluster")['Year'].count()
Df8_20_GB
# Out:
# C:\Users\blueh\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if sys.path[0] == '':
#     Cluster  SuperBowl Win  Playoff Wins       Wins     Dbacks  LineBackers  \
# 0         0       0.000000      0.200000   7.600000  16.521000     4.440000
# 1         1       0.000000      0.444444   8.777778   8.392222    13.198889
# 2         2       0.000000      0.400000   6.933333  10.552667    11.745333
# 3         3       0.050000      0.550000   8.900000  19.057500    15.913500
# 4         4       0.000000      0.230769   7.461538  13.569231     7.184615
# 5         5       0.000000      0.133333   6.600000  18.808667     9.277333
# 6         6       0.000000      0.541667   7.791667  15.749583     7.116250
# 7         7       0.000000      0.125000   6.875000  10.292500    14.190000
# 8         8       0.000000      0.111111   7.722222  17.276111    15.712778
# 9         9       0.000000      0.545455   6.909091   3.473636     6.728182
# 10       10       0.000000      0.300000   6.700000  16.045000    12.052000
# 11       11       0.000000      0.090909   7.000000  13.558182     7.010909
# 12       12       0.066667      0.800000   8.666667  18.390000     9.664000
# 13       13       0.250000      1.625000   8.250000  22.742500    21.541250
# 14       14       0.000000      0.750000   9.833333  17.262500    22.930000
# 15       15       0.000000      0.100000   6.000000   7.700000     9.082000
# 16       16       0.000000      0.307692   7.692308  17.331538     8.480000
# 17       17       0.000000      0.333333   9.083333  10.570000    11.164167
# 18       18       0.000000      0.571429   8.571429  20.427143    22.360000
# 19       19       0.066667      0.466667   7.933333  12.050000    14.078000
# 20       20       0.066667      0.533333   7.933333   5.527333    11.816000
# 21       21       0.000000      0.000000   6.100000  12.758000    11.944000
# 22       22       0.000000      0.166667   8.666667  26.281667    10.408333
# 23       23       0.083333      0.750000   8.666667   9.270000     7.208333
# 24       24       0.000000      0.533333   9.066667  14.307333    18.220000
# 25       25       0.000000      0.388889   8.611111  17.664444    13.821111
# 26       26       0.333333      1.666667  10.666667   5.870000    11.510000
# 27       27       0.000000      0.300000   8.300000  11.024000     7.524000
# 28       28       0.142857      0.857143   9.285714  11.085714    16.485714
# 29       29       0.000000      0.076923   7.384615   8.210000     7.756154
# 30       30       0.000000      0.250000   8.750000  15.083333    11.824167
# 31       31       0.000000      0.750000   8.750000  18.545000    19.925000
# 32       32       0.133333      0.933333   9.000000  12.926667    16.652000
# 33       33       0.000000      0.076923   7.461538  10.459231     6.914615
# 34       34       0.083333      0.916667   8.083333  21.790833     9.959167
# 35       35       0.000000      0.692308   7.307692  11.138462     6.720769
# 36       36       0.000000      0.466667   7.733333   6.019333     3.401333
# 37       37       0.000000      0.250000   7.750000   5.900000     3.792500
# 38       38       0.100000      0.750000   8.600000  10.920500     5.073000
# 39       39       0.000000      0.285714   7.000000  18.422857     9.958571
#
#         Dline  PassCatchers      Oline         QB        RB   Special  \
# 0    6.766000     13.258000   6.519000   5.159000  2.868000  1.938000
# 1   22.364444     14.752222  14.282222  10.315556  4.592222  2.814444
# 2   10.275333     11.629333  15.212667  13.144000  3.069333  2.434667
# 3   10.427000     18.488000  13.734500   5.770500  4.796500  2.926500
# 4   11.721538      6.154615   8.760769  10.327692  3.946923  1.877692
# 5   13.816667     14.176000  19.259333   4.639333  4.236000  2.081333
# 6   22.375000     12.960000  16.811667   7.172083  4.748333  2.455417
# 7   17.681250     16.302500  26.600000   4.511250  5.423750  3.262500
# 8   11.417778      9.402778  17.905000   6.323889  4.997778  2.862778
# 9    8.512727      8.022727   5.870000   2.191818  6.523636  1.455455
# 10  20.464000     12.896000   7.950000   6.397000  7.963000  4.489000
# 11  17.933636     21.226364  13.363636  12.906364  4.120000  2.453636
# 12  18.442000     12.096000  14.696667  13.808000  4.562000  2.800667
# 13  14.705000     15.075000  14.208750   6.877500  6.426250  3.855000
# 14   8.418333     12.250833  17.550833  12.244167  3.767500  2.200833
# 15   4.826000     10.087000  12.839000   4.135000  3.721000  2.055000
# 16  11.870769     13.712308  21.407692  13.387692  3.928462  2.760000
# 17  13.664167     14.780833  13.365833  13.616667  8.529167  3.091667
# 18   6.322857     17.472857  10.771429  14.757143  4.494286  2.584286
# 19  12.730000     17.211333  14.618000   6.972667  3.437333  2.760667
# 20   9.655333      7.476000   9.418667   9.258667  7.731333  1.243333
# 21   6.949000     14.642000  20.963000   5.622000  6.808000  2.816000
# 22  16.455000      9.860000  17.151667   8.541667  4.150000  3.341667
# 23  15.700000     19.061667  19.601667  13.214167  3.299167  2.488333
# 24  15.406667     12.209333  12.932667   9.388667  4.550000  3.296667
# 25   6.801667     14.236111  16.947778  14.502778  3.863333  3.639444
# 26   6.596667     24.000000   7.996667   8.016667  3.416667  2.610000
# 27  24.513000     19.960000  18.049000   4.788000  4.441000  2.889000
# 28   7.302857     10.840000  11.144286  13.507143  7.535714  2.054286
# 29  14.322308      6.806923   6.720769   4.592308  3.862308  2.183846
# 30  17.618333     16.391667  16.813333   6.616667  6.358333  2.639167
# 31   3.212500     10.750000   3.810000   5.545000  5.707500  0.510000
# 32   7.592667     20.326667  15.959333  13.148000  3.430000  2.747333
# 33  25.731538     10.923846  13.187692   5.335385  6.924615  2.792308
# 34  11.225000     16.763333  11.604167  11.160833  5.897500  3.060833
# 35  13.075385     10.006923  22.040000   9.728462  5.113846  2.699231
# 36   7.502667      8.103333   6.478000  10.484667  3.224667  2.011333
# 37   3.600000     17.595000  11.690000   8.020000  8.640000  1.140000
# 38  12.373000     10.478000  12.250500   9.731000  5.063500  1.843000
# 39  26.037143     12.947143  13.474286  16.251429  5.274286  2.974286
#
#         TotCap  Count
# 0    57.469000     10
# 1    90.712222      9
# 2    78.063333     15
# 3    91.114000     20
# 4    63.543077     13
# 5    86.294667     15
# 6    89.388333     24
# 7    98.263750      8
# 8    85.898889     18
# 9    42.778182     11
# 10   88.256000     10
# 11   92.572727     11
# 12   94.459333     15
# 13  105.431250      8
# 14   96.625000     12
# 15   54.445000     10
# 16   92.878462     13
# 17   88.782500     12
# 18   99.190000      7
# 19   83.858000     15
# 20   62.126667     15
# 21   82.502000     10
# 22   96.190000      6
# 23   89.843333     12
# 24   90.311333     15
# 25   91.476667     18
# 26   70.016667      3
# 27   93.188000     10
# 28   79.955714      7
# 29   54.454615     13
# 30   93.345000     12
# 31   68.005000      4
# 32   92.782667     15
# 33   82.269231     13
# 34   91.461667     12
# 35   80.523077     13
# 36   47.225333     15
# 37   60.377500      4
# 38   67.732500     20
# 39  105.340000      7

# %%
## Calculate Average Prediction Error
for i in range(0,40):
    Df8_20Clust[i] = 0

def DistFunc(x):
    Dlist = []
    TotD = 0
    for i in range(0,40):
        D = np.sqrt((x['Dbacks']-Df8_20_GB.iat[i,4])**2+(x['LineBackers'] - Df8_20_GB.iat[i,5])**2 + (x['Dline'] - Df8_20_GB.iat[i,6])**2
                +(x['PassCatchers']-Df8_20_GB.iat[i,7])**2+(x['Oline']-Df8_20_GB.iat[i,8])**2+(x['QB']-Df8_20_GB.iat[i,9])**2
                +(x['RB']-Df8_20_GB.iat[i,10])**2+(x['Special']-Df8_20_GB.iat[i,11])**2)
        Dlist.append(D)
        TotD += D


    Nlist = []
    TotN = 0
    for i in range(0,40):
        N = 1/((Dlist[i])/TotN)

        Nlist.append(N)
        TotN += N

    Perclist = []
    for i in range (0,40):
        Perc = Nlist[i]/TotN*100
        
        Perclist.append(Perc)
        

        return pd.Series(Perclist)

def ExpectedWins(x):
    WinShares = 0
    for i in range(0,40):
        WinShares += x[i]/100*Df8_20_GB.iat[i,3]
    return WinShares

Df8_20Clust[range(0,40)] = Df8_20Clust.apply(DistFunc, axis = 1)
    
Df8_20Clust['ExpWins'] = Df8_20Clust.apply(ExpectedWins, axis = 1)
Df8_20Clust['Error'] = abs(Df8_20Clust['Wins'] - Df8_20Clust['ExpWins'])
AvgError = sum(Df8_20Clust['Error'])/len(Df8_20Clust)
# Out:
# C:\Users\blueh\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: RuntimeWarning: divide by zero encountered in double_scalars
# C:\Users\blueh\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: RuntimeWarning: invalid value encountered in double_scalars

# %%
AvgError
# Out:
# 7.98125
