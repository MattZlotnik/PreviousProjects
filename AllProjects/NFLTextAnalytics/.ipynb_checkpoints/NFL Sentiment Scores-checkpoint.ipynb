# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()
import matplotlib.pyplot as plt
import numpy as np

# %%
databeyond = pd.read_csv("CleanedNFL")
datausa = pd.read_csv("CleanedNFLJustUSA")
cities = pd.read_csv("big_cities_without_a_team.csv")

# %%
def sentiment_analyzer_scores(sentence):
    score = analyser.polarity_scores(sentence)
    print("{:-<40} {}".format(sentence, str(score)))

# %%
databeyond['tw_sentiment_neg'] = databeyond['tweet'].apply(lambda x :analyser.polarity_scores(x)['neg'])
databeyond['tw_sentiment_neu'] = databeyond['tweet'].apply(lambda x :analyser.polarity_scores(x)['neu'])
databeyond['tw_sentiment_pos'] = databeyond['tweet'].apply(lambda x :analyser.polarity_scores(x)['pos'])
databeyond['ht_sentiment_neg'] = databeyond['hashtags_clean'].apply(lambda x :analyser.polarity_scores(x)['neg'])
databeyond['ht_sentiment_neu'] = databeyond['hashtags_clean'].apply(lambda x :analyser.polarity_scores(x)['neu'])
databeyond['ht_sentiment_pos'] = databeyond['hashtags_clean'].apply(lambda x :analyser.polarity_scores(x)['pos'])

datausa['tw_sentiment_neg'] = datausa['tweet'].apply(lambda x :analyser.polarity_scores(x)['neg'])
datausa['tw_sentiment_neu'] = datausa['tweet'].apply(lambda x :analyser.polarity_scores(x)['neu'])
datausa['tw_sentiment_pos'] = datausa['tweet'].apply(lambda x :analyser.polarity_scores(x)['pos'])
datausa['ht_sentiment_neg'] = datausa['hashtags_clean'].apply(lambda x :analyser.polarity_scores(x)['neg'])
datausa['ht_sentiment_neu'] = datausa['hashtags_clean'].apply(lambda x :analyser.polarity_scores(x)['neu'])
datausa['ht_sentiment_pos'] = datausa['hashtags_clean'].apply(lambda x :analyser.polarity_scores(x)['pos'])

# %%
sentnotusa = databeyond.groupby(by = 'City').mean()
sentusa = datausa.groupby(by = 'City').mean()

# %%
sentnotusa.sort_values(by = 'tw_sentiment_pos', ascending = False)
sentnotusa.sort_values(by = 'ht_sentiment_pos', ascending = False)
# Out:
#              Unnamed: 0  tweet_count  tw_sentiment_neg  tw_sentiment_neu  \
# City
# Toronto          1281.0        209.0          0.048735          0.870847
# Montreal         1560.0         69.0          0.041525          0.876388
# Mexico City       249.5        249.5          0.019524          0.968530
# Paris            1035.5         35.5          0.036139          0.914986
# London            749.5        249.5          0.025194          0.888076
# Madrid           2027.0         91.0          0.003273          0.974503
# Vancouver        1730.0        100.0          0.032592          0.869851
# Barcelona        1905.0         30.0          0.016689          0.962164
# Lisbon           1867.5          6.5          0.007286          0.979571
# Quebec           1845.5         14.5          0.028933          0.922933
#
#              tw_sentiment_pos  ht_sentiment_neg  ht_sentiment_neu  \
# City
# Toronto              0.080430          0.004325          0.969921
# Montreal             0.082115          0.000000          0.976770
# Mexico City          0.011948          0.001994          0.982044
# Paris                0.048861          0.000000          0.988194
# London               0.086726          0.007292          0.981694
# Madrid               0.022224          0.000650          0.993426
# Vancouver            0.097567          0.000000          0.995552
# Barcelona            0.021148          0.000000          0.996590
# Lisbon               0.013143          0.000000          1.000000
# Quebec               0.048100          0.000000          1.000000
#
#              ht_sentiment_pos
# City
# Toronto              0.025754
# Montreal             0.023230
# Mexico City          0.015962
# Paris                0.011806
# London               0.011014
# Madrid               0.005923
# Vancouver            0.004448
# Barcelona            0.003410
# Lisbon               0.000000
# Quebec               0.000000

# %%
sentusa.sort_values(by = 'tw_sentiment_pos', ascending = False)
sentusa.sort_values(by = 'ht_sentiment_pos', ascending = False)
# Out:
#                    Unnamed: 0  tweet_count  tw_sentiment_neg  \
# City
# Baton Rouge           31463.0         44.0          0.019157
# Lexington-Fayette     22017.0         13.0          0.025889
# Corpus Christi        21986.5         16.5          0.028235
# Raleigh               16337.0         74.0          0.047523
# Laredo                27988.5         10.5          0.022136
# ...                       ...          ...               ...
# Cincinnati            22838.5        162.5          0.055163
# Oklahoma City         11959.5         74.5          0.061640
# Bakersfield           19579.0         13.0          0.027556
# St. Petersburg        27475.5          1.5          0.034750
# Tulsa                 17947.5         35.5          0.052056
#
#                    tw_sentiment_neu  tw_sentiment_pos  ht_sentiment_neg  \
# City
# Baton Rouge                0.911843          0.068989          0.007292
# Lexington-Fayette          0.916741          0.057333          0.000000
# Corpus Christi             0.868500          0.103265          0.000000
# Raleigh                    0.852993          0.099490          0.000000
# Laredo                     0.950273          0.027591          0.000000
# ...                             ...               ...               ...
# Cincinnati                 0.857298          0.087540          0.004199
# Oklahoma City              0.832767          0.105593          0.002540
# Bakersfield                0.899185          0.073222          0.013444
# St. Petersburg             0.946500          0.018750          0.000000
# Tulsa                      0.882042          0.065931          0.005528
#
#                    ht_sentiment_neu  ht_sentiment_pos
# City
# Baton Rouge                0.901899          0.090809
# Lexington-Fayette          0.924444          0.075556
# Corpus Christi             0.934941          0.065059
# Raleigh                    0.942799          0.057201
# Laredo                     0.945000          0.055000
# ...                             ...               ...
# Cincinnati                 0.993218          0.002583
# Oklahoma City              0.994987          0.002473
# Bakersfield                0.986556          0.000000
# St. Petersburg             1.000000          0.000000
# Tulsa                      0.994472          0.000000
#
# [99 rows x 8 columns]

# %%
NFL_Cities = ['Los Angeles', 'Denver', 'Kansas City', 'Oakland', 'Phoenix', 'San Francisco', 'Seattle', 'Atlanta', 'Charlotte', 'New Orleans', 'Tampa Bay', 'Houston', 'Jacksonville', 'Nashville', 'Indianapolis', 'Chicago', 'Detroit', 'Minneapolis', 'St. Paul', 'Pittsburgh', 'Cleveland', 'Cincinatti', 'Baltimore', 'Dallas', 'Fort Worth', 'New York', 'Philadelphia', 'Washington', 'Buffalo', 'Miami', 'Boston']

# %%
datasets = [datausa, databeyond]
NFLCitiesData = pd.DataFrame(columns = datausa.columns)
NotNFLCitiesData = pd.DataFrame(columns = datausa.columns)
for dataset in datasets:
    for i in range(0,len(dataset)):
        row = dataset.iloc[i:i+1]
        if row['City'].values[0] in NFL_Cities:
            NFLCitiesData = NFLCitiesData.append(row)
        elif row['City'].values[0]  not in NFL_Cities:
            NotNFLCitiesData = NotNFLCitiesData.append(row)

# %%
sentnotnfl = NotNFLCitiesData.groupby(by = 'City').mean()
sentnfl = NFLCitiesData.groupby(by = 'City').mean()

# %%
notnfl = sentnotnfl.sort_values(by = 'tw_sentiment_pos', ascending = False)[:20]
notnfl
# Out:
#                              tw_sentiment_neg  tw_sentiment_neu  \
# City
# Anchorage                            0.044571          0.817429
# Fresno                               0.064345          0.811483
# Greensboro                           0.039650          0.838415
# Long Beach                           0.032816          0.846148
# Tucson                               0.041767          0.841167
# Oklahoma City                        0.061640          0.832767
# San Bernardino                       0.051297          0.843804
# Madison                              0.058660          0.836698
# Riverside                            0.050304          0.845960
# Stockton                             0.048786          0.847634
# Corpus Christi                       0.028235          0.868500
# Mesa                                 0.052652          0.845562
# Glendale                             0.053296          0.847006
# Raleigh                              0.047523          0.852993
# San Jose                             0.035335          0.865522
# San Diego                            0.058230          0.842964
# Scottsdale                           0.048998          0.852422
# Louisville/Jefferson County          0.055429          0.846274
# Anaheim                              0.041034          0.861158
# Vancouver                            0.032592          0.869851
#
#                              tw_sentiment_pos  ht_sentiment_neg  \
# City
# Anchorage                            0.138000          0.037429
# Fresno                               0.124207          0.005983
# Greensboro                           0.121943          0.005276
# Long Beach                           0.121028          0.009870
# Tucson                               0.117050          0.000000
# Oklahoma City                        0.105593          0.002540
# San Bernardino                       0.104873          0.011741
# Madison                              0.104623          0.009283
# Riverside                            0.103719          0.011062
# Stockton                             0.103550          0.017237
# Corpus Christi                       0.103265          0.000000
# Mesa                                 0.101800          0.008280
# Glendale                             0.099706          0.005398
# Raleigh                              0.099490          0.000000
# San Jose                             0.099145          0.007280
# San Diego                            0.098806          0.009308
# Scottsdale                           0.098588          0.007500
# Louisville/Jefferson County          0.098343          0.023251
# Anaheim                              0.097812          0.011090
# Vancouver                            0.097567          0.000000
#
#                              ht_sentiment_neu  ht_sentiment_pos
# City
# Anchorage                            0.946929          0.015643
# Fresno                               0.972345          0.021672
# Greensboro                           0.959634          0.035089
# Long Beach                           0.983262          0.006868
# Tucson                               0.961600          0.038400
# Oklahoma City                        0.994987          0.002473
# San Bernardino                       0.966481          0.021778
# Madison                              0.976811          0.013906
# Riverside                            0.964540          0.024397
# Stockton                             0.973382          0.009382
# Corpus Christi                       0.934941          0.065059
# Mesa                                 0.973062          0.018658
# Glendale                             0.973480          0.021122
# Raleigh                              0.942799          0.057201
# San Jose                             0.969611          0.023110
# San Diego                            0.979414          0.011278
# Scottsdale                           0.973008          0.019492
# Louisville/Jefferson County          0.962731          0.014017
# Anaheim                              0.982044          0.006866
# Vancouver                            0.995552          0.004448

# %%
#AllCitiesSent = sentnotnfl.append(sentnfl)

# %%
#sentnfl.sort_values(by = 'tw_sentiment_pos', ascending = False)

# %%
nflpops = pd.read_csv('teams_with_stadium.csv', encoding = 'Latin-1')
nflpops = nflpops.set_index('city')
datausa.set_index('City', inplace = True)

# %%
cities.drop('Unnamed: 0', axis = 1, inplace = True)
nflpops.drop('Unnamed: 0', axis = 1, inplace = True)
datausa.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
# combinednfl = datausa.join(nflpops, how = 'inner')
# combinednfl.reset_index(inplace = True)
# cities.set_index('city', inplace = True)
# databeyond.set_index('City', inplace = True)
# NotNFLCitiesData.set_index('City', inplace = True)
# combinednotnfl = NotNFLCitiesData.join(cities, how = 'inner')
# combinednotnfl.reset_index(inplace = True)
# combinednfl.rename(columns = {'index': 'City'}, inplace = True)
tobemergednfl = combinednfl[['tw_sentiment_neg', 'tw_sentiment_neu', 'tw_sentiment_pos', 'ht_sentiment_neg', 'ht_sentiment_neu', 'ht_sentiment_pos', 'population', 'City']]
tobemergednotnfl = combinednotnfl[['tw_sentiment_neg', 'tw_sentiment_neu', 'tw_sentiment_pos', 'ht_sentiment_neg', 'ht_sentiment_neu', 'ht_sentiment_pos', 'population', 'index']]
tobemergednotnfl.rename(columns = {'index': 'City'}, inplace = True)
# Out:
# C:\Users\blueh\Anaconda3\lib\site-packages\pandas\core\frame.py:4223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)

# %%
final_df = tobemergednfl.append(tobemergednotnfl)
final_df_grouped = final_df.groupby(by = 'City').mean()

# %%
final_df_grouped.sort_values(by = 'tw_sentiment_pos', ascending = False)
final_df_grouped['combinedsentiment'] = final_df_grouped['tw_sentiment_pos'] + final_df_grouped['tw_sentiment_neg'] + final_df_grouped['ht_sentiment_pos'] + final_df_grouped['ht_sentiment_neg']
final_df_grouped.sort_values(by = 'combinedsentiment', ascending = False)
# Out:
#                              tw_sentiment_neg  tw_sentiment_neu  \
# City
# Fresno                               0.064345          0.811483
# Raleigh                              0.047523          0.852993
# Memphis                              0.071209          0.831615
# Tucson                               0.041767          0.841167
# Louisville/Jefferson County          0.055429          0.846274
# Baltimore                            0.053696          0.846224
# Albuquerque                          0.067264          0.845311
# San Diego                            0.058230          0.842964
# Phoenix                              0.052156          0.848080
# New Orleans                          0.043922          0.873754
# Wichita                              0.077049          0.838024
# Portland                             0.054156          0.851445
# Minneapolis                          0.041622          0.869082
# Pittsburgh                           0.066090          0.841190
# Oklahoma City                        0.061640          0.832767
# Houston                              0.061278          0.856204
# Detroit                              0.050326          0.862338
# Washington                           0.060770          0.850310
# Chicago                              0.053664          0.865292
# Kansas City                          0.038904          0.860672
# Columbus                             0.051464          0.863368
# Boston                               0.060252          0.855594
# Los Angeles                          0.041594          0.878298
# Sacramento                           0.053521          0.862498
# Cleveland                            0.079422          0.850940
# San Antonio                          0.046411          0.863782
# Milwaukee                            0.056014          0.855937
# Denver                               0.057486          0.859068
# Seattle                              0.048946          0.871424
# Colorado Springs                     0.049667          0.859783
# Atlanta                              0.052866          0.879088
# Indianapolis                         0.041042          0.864894
# New York                             0.049282          0.866802
# El Paso                              0.033800          0.897214
# Cincinnati                           0.055163          0.857298
# Dallas                               0.052064          0.871988
# Oakland                              0.035778          0.871508
# Charlotte                            0.039588          0.877600
# San Francisco                        0.033726          0.873362
# Buffalo                              0.048728          0.868480
# Philadelphia                         0.054154          0.871620
# Austin                               0.044094          0.869356
# Miami                                0.046694          0.878880
# Nashville-Davidson                   0.040552          0.885644
# Virginia Beach                       0.029831          0.916009
# Tulsa                                0.052056          0.882042
# Omaha                                0.042088          0.898192
# San Antonio                          0.978032          0.015968     1409019
# Milwaukee                            0.987118          0.009387      599164
# Denver                               0.986432          0.006076      649495
# Seattle                              0.975348          0.014478      652405
# Colorado Springs                     0.987616          0.010080      439886
# Atlanta                              0.968954          0.024224      447841
# Indianapolis                         0.984162          0.010216      843393
# New York                             0.982634          0.008960     8405837
# El Paso                              0.952657          0.047343      674433
# Cincinnati                           0.993218          0.002583      297517
# Dallas                               0.983072          0.009524     1257676
# Oakland                              0.983786          0.008342      406253
# Charlotte                            0.977930          0.015150      792862
# San Francisco                        0.982852          0.008992      837442
# Buffalo                              0.988092          0.007330      258959
# Philadelphia                         0.985524          0.009948     1553165
# Austin                               0.989558          0.005538      885400
# Miami                                0.984978          0.014644      417650
# Nashville-Davidson                   0.978820          0.014330      634464
# Virginia Beach                       0.955169          0.032142      448479
# Tulsa                                0.994472          0.000000      398121
# Omaha                                0.985864          0.012512      434353
# Jacksonville                         0.960746          0.037534      842583
# Las Vegas                            0.987394          0.011218      603488
#
#                              combinedsentiment
# City
# Fresno                                0.216207
# Raleigh                               0.204215
# Memphis                               0.203453
# Tucson                                0.197217
# Louisville/Jefferson County           0.191040
# Baltimore                             0.182436
# Albuquerque                           0.181585
# San Diego                             0.177622
# Phoenix                               0.176798
# New Orleans                           0.176682
# Wichita                               0.176171
# Portland                              0.174751
# Minneapolis                           0.173348
# Pittsburgh                            0.173336
# Oklahoma City                         0.172247
# Houston                               0.170710
# Detroit                               0.170030
# Washington                            0.168326
# Chicago                               0.163040
# Kansas City                           0.162554
# Columbus                              0.162461
# Boston                                0.161974
# Los Angeles                           0.161498
# Sacramento                            0.160100
# Cleveland                             0.158518
# San Antonio                           0.158182
# Milwaukee                             0.156958
# Denver                                0.154496
# Seattle                               0.153230
# Colorado Springs                      0.152601
# Atlanta                               0.151958
# Indianapolis                          0.150954
# New York                              0.150576
# El Paso                               0.150100
# Cincinnati                            0.149485
# Dallas                                0.144946
# Oakland                               0.144714
# Charlotte                             0.144472
# San Francisco                         0.143794
# Buffalo                               0.143422
# Philadelphia                          0.142858
# Austin                                0.141088
# Miami                                 0.136136
# Nashville-Davidson                    0.135522
# Virginia Beach                        0.128817
# Tulsa                                 0.123514
# Omaha                                 0.115960
# Jacksonville                          0.106962
# Las Vegas                             0.052378

# %%
final_df_grouped.drop(['New York', 'Los Angeles', 'Chicago'], axis = 0, inplace = True)
fig, ax = plt.subplots(figsize = (10,10))
ax.scatter(final_df_grouped['combinedsentiment'], final_df_grouped['population'])
for i, txt in enumerate(final_df_grouped.index):
    ax.annotate(txt, (final_df_grouped['combinedsentiment'][i], final_df_grouped['population'][i]))

# %%
smallercities = final_df_grouped[final_df_grouped['population'] <= 1000000]

# %%
fig, ax = plt.subplots(figsize = (10,10))
ax.scatter(smallercities['combinedsentiment'], smallercities['population'])

for i, txt in enumerate(smallercities.index):
    ax.annotate(txt, (smallercities['combinedsentiment'][i], smallercities['population'][i]))

# %%
sentnotusa.drop(['Unnamed: 0', 'tweet_count'], axis = 1, inplace = True)
Population = [5515000, 504718, 8900000, 6550000, 8850000, 1780000, 2141000, 542298, 2930000, 675218]
sentnotusa['population'] = Population
sentnotusa['combinedsentiment'] = sentnotusa['tw_sentiment_pos'] + sentnotusa['tw_sentiment_neg'] + sentnotusa['ht_sentiment_pos'] + sentnotusa['ht_sentiment_neg']
sentnotusa
# Out:
#              tw_sentiment_neg  tw_sentiment_neu  tw_sentiment_pos  \
# City
# Barcelona            0.016689          0.962164          0.021148
# Lisbon               0.007286          0.979571          0.013143
# London               0.025194          0.888076          0.086726
# Madrid               0.003273          0.974503          0.022224
# Mexico City          0.019524          0.968530          0.011948
# Montreal             0.041525          0.876388          0.082115
# Paris                0.036139          0.914986          0.048861
# Quebec               0.028933          0.922933          0.048100
# Toronto              0.048735          0.870847          0.080430
# Vancouver            0.032592          0.869851          0.097567
#
#              ht_sentiment_neg  ht_sentiment_neu  ht_sentiment_pos  population  \
# City
# Barcelona            0.000000          0.996590          0.003410     5515000
# Lisbon               0.000000          1.000000          0.000000      504718
# London               0.007292          0.981694          0.011014     8900000
# Madrid               0.000650          0.993426          0.005923     6550000
# Mexico City          0.001994          0.982044          0.015962     8850000
# Montreal             0.000000          0.976770          0.023230     1780000
# Paris                0.000000          0.988194          0.011806     2141000
# Quebec               0.000000          1.000000          0.000000      542298
# Toronto              0.004325          0.969921          0.025754     2930000
# Vancouver            0.000000          0.995552          0.004448      675218
#
#              combinedsentiment
# City
# Barcelona             0.041246
# Lisbon                0.020429
# London                0.130226
# Madrid                0.032071
# Mexico City           0.049428
# Montreal              0.146871
# Paris                 0.096806
# Quebec                0.077033
# Toronto               0.159243
# Vancouver             0.134607

# %%
fig, ax = plt.subplots(figsize = (10,10))
ax.scatter(sentnotusa['combinedsentiment'], sentnotusa['population'])
for i, txt in enumerate(sentnotusa.index):
    ax.annotate(txt, (sentnotusa['combinedsentiment'][i], sentnotusa['population'][i]))

# %%
AllCitiesGrouped = final_df_grouped.append(sentnotusa)
fig, ax = plt.subplots(figsize = (10,10))
ax.scatter(AllCitiesGrouped['combinedsentiment'], AllCitiesGrouped['population'])
for i, txt in enumerate(AllCitiesGrouped.index):
    ax.annotate(txt, (AllCitiesGrouped['combinedsentiment'][i], AllCitiesGrouped['population'][i]))

# %%
final_df_grouped
# Out:
#                              tw_sentiment_neg  tw_sentiment_neu  \
# City
# Albuquerque                          0.067264          0.845311
# Atlanta                              0.052866          0.879088
# Austin                               0.044094          0.869356
# Baltimore                            0.053696          0.846224
# Boston                               0.060252          0.855594
# Buffalo                              0.048728          0.868480
# Charlotte                            0.039588          0.877600
# Cincinnati                           0.055163          0.857298
# Cleveland                            0.079422          0.850940
# Colorado Springs                     0.049667          0.859783
# Columbus                             0.051464          0.863368
# Dallas                               0.052064          0.871988
# Denver                               0.057486          0.859068
# Detroit                              0.050326          0.862338
# El Paso                              0.033800          0.897214
# Fresno                               0.064345          0.811483
# Houston                              0.061278          0.856204
