# %%
import pandas as pd

df_sample = pd.read_csv('1000 reviews with normalized scores.csv')
#df_sample.columns.values
df_sample = df_sample.rename(columns = {'Unnamed: 0':'Index'}).set_index('Index')
df_sample.head()
# Out:
#                   business_id  cool                 date  funny  \
# Index
# 84442  XH2TZmZt6gzHHpjqk8C6pg     1  2009-05-26 13:42:02      3
# 75795  yNVcnSaMSrTmjJBMrHTy9w     2  2012-06-01 18:22:23      1
# 42057  zk3AimWhuz0EZsNgIddKdg     0  2018-05-19 16:05:50      0
# 25891  MN0Pd66285k2k9lkpEtptA     0  2017-03-15 20:01:16      0
# 51127  N9oZ9GDPf65x6zv7fsKJvA     0  2012-11-07 23:02:55      1
#
#                     review_id  stars  useful                 user_id  \
# Index
# 84442  rtQJU6GHxnxsXKBspKzWaA      5       6  lJzgOpVS1pmb2UW7j2GkDg
# 75795  wU-awV0uGkZdjnIFsgoTQA      4       5  8iqGB11mHwCTLOOHkqnqmQ
# 42057  WBE8cGKMIJggpXRA4KTaog      2       0  qFk5mtbEqpRgg2v2HRoryQ
# 25891  _NcurWksF9tSwXK9Mq3GIA      1       0  D4xs1lDiug7hU_NfPnJxpQ
# 51127  bQ1zd9OOjNwMJexVp2jZSA      3       2  cuVrNmt7_WtBn1uz5L_p0g
#
#        fear_score  happy_score  ...  neutral_score  surprise_score  \
# Index                           ...
# ...

# %%
df_full_reviews = pd.read_json('yelp_academic_dataset_review_cleaned.json', lines = True)
df_full_sample = df_full_reviews.iloc[df_sample.index.values]
df_full_sample.head()

df_sample['text'] = df_full_sample['text']
df_sample.head()
# Out:
#                   business_id  cool                 date  funny  \
# Index
# 84442  XH2TZmZt6gzHHpjqk8C6pg     1  2009-05-26 13:42:02      3
# 75795  yNVcnSaMSrTmjJBMrHTy9w     2  2012-06-01 18:22:23      1
# 42057  zk3AimWhuz0EZsNgIddKdg     0  2018-05-19 16:05:50      0
# 25891  MN0Pd66285k2k9lkpEtptA     0  2017-03-15 20:01:16      0
# 51127  N9oZ9GDPf65x6zv7fsKJvA     0  2012-11-07 23:02:55      1
#
#                     review_id  stars  useful                 user_id  \
# Index
# 84442  rtQJU6GHxnxsXKBspKzWaA      5       6  lJzgOpVS1pmb2UW7j2GkDg
# 75795  wU-awV0uGkZdjnIFsgoTQA      4       5  8iqGB11mHwCTLOOHkqnqmQ
# 42057  WBE8cGKMIJggpXRA4KTaog      2       0  qFk5mtbEqpRgg2v2HRoryQ
# 25891  _NcurWksF9tSwXK9Mq3GIA      1       0  D4xs1lDiug7hU_NfPnJxpQ
# 51127  bQ1zd9OOjNwMJexVp2jZSA      3       2  cuVrNmt7_WtBn1uz5L_p0g
#
#        fear_score  happy_score  ...  surprise_score  disgust_score  \
# Index                           ...
# ...

# %%
import re

def review_length(s):
    return len(re.split('\s',s))

df_sample['review_length'] = df_sample['text'].map(review_length)
df_sample.head()
# Out:
#                   business_id  cool                 date  funny  \
# Index
# 84442  XH2TZmZt6gzHHpjqk8C6pg     1  2009-05-26 13:42:02      3
# 75795  yNVcnSaMSrTmjJBMrHTy9w     2  2012-06-01 18:22:23      1
# 42057  zk3AimWhuz0EZsNgIddKdg     0  2018-05-19 16:05:50      0
# 25891  MN0Pd66285k2k9lkpEtptA     0  2017-03-15 20:01:16      0
# 51127  N9oZ9GDPf65x6zv7fsKJvA     0  2012-11-07 23:02:55      1
#
#                     review_id  stars  useful                 user_id  \
# Index
# 84442  rtQJU6GHxnxsXKBspKzWaA      5       6  lJzgOpVS1pmb2UW7j2GkDg
# 75795  wU-awV0uGkZdjnIFsgoTQA      4       5  8iqGB11mHwCTLOOHkqnqmQ
# 42057  WBE8cGKMIJggpXRA4KTaog      2       0  qFk5mtbEqpRgg2v2HRoryQ
# 25891  _NcurWksF9tSwXK9Mq3GIA      1       0  D4xs1lDiug7hU_NfPnJxpQ
# 51127  bQ1zd9OOjNwMJexVp2jZSA      3       2  cuVrNmt7_WtBn1uz5L_p0g
#
#        fear_score  happy_score  ...  disgust_score  fear_normalized  \
# Index                           ...
# ...

# %%
df_sample.to_csv('1000 reviews with normalized scores.csv')
